# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
file = "C:/Users/stanl/Documents/OneCampus_release_Materials/Workspace/dataset/bank/bank-full.csv"
df = pd.read_csv(file, sep=';')

# %%
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Check the data structure 

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %%
df.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
#Age

df.age.plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df.balance.plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df.pdays.plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
#Uniuvariate Analysis

# Analyze the vocation of the customers for insight 
sb.set(rc={'figure.figsize':(15,8.27)})

ax = sb.countplot(x='job', data = df)

# %%
plt.figure(figsize=(8,7))
sb.countplot(x='education', data=df)
# Out:
# <AxesSubplot:xlabel='education', ylabel='count'>

# %%
plt.figure(figsize=(8,7))
sb.countplot(x='default', data=df)
# Out:
# <AxesSubplot:xlabel='default', ylabel='count'>

# %%
#Label Encoding
print(df.head(2))
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   58  management  married   tertiary      no     2143     yes   no  unknown
# 1   44  technician   single  secondary      no       29     yes   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome   y
# 0    5   may       261         1     -1         0  unknown  no
# 1    5   may       151         1     -1         0  unknown  no

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
# Categorical variables in our data:abs

catFeature = [col for col in df.columns if pd.api.types.is_string_dtype(df[col])] # list comprehension
print(catFeature)
labelDict = {}
for col in catFeature:
    labels = df[col].unique()
    labelDict[col] = labels
# Out:
# ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'poutcome', 'y']

# %%
labelDict['job']
# Out:
# array(['management', 'technician', 'entrepreneur', 'blue-collar',
#        'unknown', 'retired', 'admin.', 'services', 'self-employed',
#        'unemployed', 'housemaid', 'student'], dtype=object)

# %%
labelDict['marital']
# Out:
# array(['married', 'single', 'divorced'], dtype=object)

# %%
labelDict.keys()
# Out:
# dict_keys(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'poutcome', 'y'])

# %%
labelDict.values()
# Out:
# dict_values([array(['management', 'technician', 'entrepreneur', 'blue-collar',
#        'unknown', 'retired', 'admin.', 'services', 'self-employed',
#        'unemployed', 'housemaid', 'student'], dtype=object), array(['married', 'single', 'divorced'], dtype=object), array(['tertiary', 'secondary', 'unknown', 'primary'], dtype=object), array(['no', 'yes'], dtype=object), array(['yes', 'no'], dtype=object), array(['no', 'yes'], dtype=object), array(['unknown', 'cellular', 'telephone'], dtype=object), array(['may', 'jun', 'jul', 'aug', 'oct', 'nov', 'dec', 'jan', 'feb',
#        'mar', 'apr', 'sep'], dtype=object), array(['unknown', 'failure', 'other', 'success'], dtype=object), array(['no', 'yes'], dtype=object)])

# %%
cols = df.columns.tolist()
catFeature1 = []
for col in cols:
    # check the content of the col to see if its stringsabs
    if pd.api.types.is_string_dtype(df[col]):
        catFeature1.append(col)

# %%
catFeature1
# Out:
# ['job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'poutcome',
#  'y']

# %%
cols = df.columns.tolist()
catFeature2 = []
for col in cols:
    uniqVals = df[col].unique()
    typ = type(uniqVals[0])
    if typ == str:
        catFeature2.append(col)

# %%
cols = df.columns.tolist()
catFeature1 = []
catFeature2 = []
for col in cols:
    # check the content of the col to see if its stringsabs
    uniqVals = df[col].unique()
    #print(uniqVals)
    #print(type(uniqVals[0]))
    typ = type(uniqVals[0])
    print(typ)
    if typ == str:
        print(uniqVals)
        print(f'this col,{col } is a string')
        catFeature2.append(col)
# Out:
# <class 'numpy.int64'>
# <class 'str'>
# ['management' 'technician' 'entrepreneur' 'blue-collar' 'unknown'
#  'retired' 'admin.' 'services' 'self-employed' 'unemployed' 'housemaid'
#  'student']
# this col,job is a string
# <class 'str'>
# ['married' 'single' 'divorced']
# this col,marital is a string
# <class 'str'>
# ['tertiary' 'secondary' 'unknown' 'primary']
# this col,education is a string
# <class 'str'>
# ['no' 'yes']
# this col,default is a string
# <class 'numpy.int64'>
# <class 'str'>
# ['yes' 'no']
# this col,housing is a string
# <class 'str'>
# ['no' 'yes']
# this col,loan is a string
# <class 'str'>
# ['unknown' 'cellular' 'telephone']
# this col,contact is a string
# <class 'numpy.int64'>
# <class 'str'>
# ['may' 'jun' 'jul' 'aug' 'oct' 'nov' 'dec' 'jan' 'feb' 'mar' 'apr' 'sep']
# this col,month is a string
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'str'>
# ['unknown' 'failure' 'other' 'success']
# ...

# %%
catFeature2
# Out:
# ['job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'poutcome',
#  'y']

# %%
df['job']
# Out:
# 0          management
# 1          technician
# 2        entrepreneur
# 3         blue-collar
# 4             unknown
#              ...
# 45206      technician
# 45207         retired
# 45208         retired
# 45209     blue-collar
# 45210    entrepreneur
# Name: job, Length: 45211, dtype: object

# %%
len(df.columns)
# Out:
# 17

# %%
cols
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'balance',
#  'housing',
#  'loan',
#  'contact',
#  'day',
#  'month',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'poutcome',
#  'y']

# %%
sb.pairplot(df, )

# %%
df.plot(kind='density', subplots=True,layout= (4,5), sharex=False)
plt.gcf().set_size_inches(30,30)
plt.show()
